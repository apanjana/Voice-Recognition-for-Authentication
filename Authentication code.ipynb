# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from python_speech_features import mfcc
import librosa
import pygame
import os
import noisereduce as nr
from scipy.io import wavfile
import soundfile as sf
import sounddevice as sd
import logging
logger = logging.getLogger()
logger.setLevel(logging.ERROR)
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Load audio files for two speakers
spk1, sr1 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a001.wav")
spk2, sr2 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a002.wav")
spk3, sr3 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a003.wav")
spk4, sr4 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a004.wav")
spk5, sr5 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a005.wav")
spk6, sr6 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a006.wav")
spk7, sr7 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a007.wav")
spk8, sr8 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a008.wav")
spk9, sr9 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a009.wav")
spk10,sr10= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a010.wav")
spk11,sr11= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a011.wav")
spk12,sr12= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a012.wav")
spk13,sr13= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a013.wav")
spk14,sr14= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a014.wav")
spk16,sr16= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a016.wav")
spk17,sr17= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a017.wav")
spk18,sr18= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a018.wav")
spk19,sr19= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a019.wav")
spk20,sr20= librosa.load("C:/Users/kpani/Anjana A P/Mini project/test/apt1.wav")
spk21,sr21= librosa.load("C:/Users/kpani/Anjana A P/Mini project/test/apt2.wav")
spk22,sr22= librosa.load("C:/Users/kpani/Anjana A P/Mini project/test/apt3.wav")
spk23,sr23= librosa.load("C:/Users/kpani/Anjana A P/Mini project/test/apt4.wav")
spk24,sr24= librosa.load("C:/Users/kpani/Anjana A P/Mini project/test/apt5.wav")
spk25,sr25= librosa.load("C:/Users/kpani/Anjana A P/Mini project/test/apt6.wav")
spk26,sr26= librosa.load("C:/Users/kpani/Anjana A P/Mini project/test/apt7.wav")
spk27,sr27= librosa.load("C:/Users/kpani/Anjana A P/Mini project/test/apt8.wav")
spk28,sr28= librosa.load("C:/Users/kpani/Anjana A P/Mini project/test/apt9.wav")
spk29,sr29= librosa.load("C:/Users/kpani/Anjana A P/Mini project/test/apt10.wav")
spk30,sr30= librosa.load("C:/Users/kpani/Anjana A P/Mini project/test/apt11.wav")
spk31,sr31= librosa.load("C:/Users/kpani/Anjana A P/Mini project/test/apt12.wav")
spk32, sr32= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a019.wav")
spk33, sr33= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a020.wav")
spk34, sr34= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a021.wav")
spk35, sr35= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a022.wav")
spk36, sr36= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a023.wav")
#spk37, sr37= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a024.wav")
spk38, sr38= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a025.wav")
spk39, sr39= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a026.wav")
spk40, sr40= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a027.wav")
spk41, sr41= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a028.wav")
spk42, sr42= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a029.wav")
spk43, sr43= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a030.wav")
spk44, sr44= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a031.wav")
spk45, sr45= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a032.wav")
spk46, sr46= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a033.wav")
spk47, sr47= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a034.wav")
spk48, sr48= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a035.wav")
spk49, sr49= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a036.wav")
spk50, sr50= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a037.wav")
spk51, sr51= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a038.wav")
spk52, sr52= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a039.wav")
spk53, sr53= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker1/a040.wav")
spk54, sr54= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Spea
librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker3/ay079.wav")
#spk3_93, sr3_93= librosa.load("C:/Users/kpani/Anjana A P/Mini project/Speaker3/ay080.wav")

# %%
spk4_1, sr4_1 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/_JpHD6VnJ3I/00001.wav")
spk4_2, sr4_2 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/_JpHD6VnJ3I/00002.wav")
spk4_3, sr4_3 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/5ablueV_1tw/00002.wav")
spk4_4, sr4_4 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/5ablueV_1tw/00003.wav")
spk4_5, sr4_5 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/5ablueV_1tw/00004.wav")
spk4_6, sr4_6 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/5ablueV_1tw/00005.wav")
spk4_7, sr4_7 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/5ablueV_1tw/00006.wav")
spk4_8, sr4_8 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/5ablueV_1tw/00007.wav")
spk4_9, sr4_9 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/5ablueV_1tw/00008.wav")
spk4_10, sr4_10 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/5ablueV_1tw/00009.wav")
spk4_11, sr4_11 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/A8SBCxYzJgs/00004.wav")
spk4_12, sr4_12 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/A8SBCxYzJgs/00001.wav")
spk4_13, sr4_13 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/A8SBCxYzJgs/00002.wav")
spk4_14, sr4_14 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/A8SBCxYzJgs/00003.wav")
spk4_32, sr4_32 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/A8SBCxYzJgs/00005.wav")
spk4_33, sr4_33 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/bDxy7bnj_bc/00005.wav")
spk4_34, sr4_34 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/bDxy7bnj_bc/00001.wav")
spk4_35, sr4_35 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/bDxy7bnj_bc/00002.wav")
spk4_36, sr4_36 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/bDxy7bnj_bc/00003.wav")
spk4_37, sr4_37 = librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/bDxy7bnj_bc/00004.wav")
spk4_77, sr4_77= librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/00016.wav")
spk4_78, sr4_78= librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/00017.wav")
spk4_79, sr4_79= librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/00018.wav")
spk4_80, sr4_80= librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/00019.wav")
spk4_81, sr4_81= librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/00020.wav")
spk4_82, sr4_82= librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/00021.wav")
spk4_83, sr4_83= librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/00022.wav")
spk4_84, sr4_84= librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/00023.wav")
spk4_85, sr4_85= librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/00024.wav")
spk4_86, sr4_86= librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/00025.wav")
spk4_87, sr4_87= librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/00026.wav")
spk4_88, sr4_88= librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/00027.wav")
spk4_89, sr4_89= librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/00028.wav")
spk4_90, sr4_90= librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/00029.wav")
spk4_91, sr4_91= librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/00030.wav")
spk4_92, sr4_92= librosa.load("C:/Users/kpani/Anjana A P/Mini project/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/00031.wav")
#spk4_93, sr4_93= librosa.load("C:/Users/kpani/Anjana A P/Mini project/archive.zipt/vox1_indian/content/vox_indian/id10003/E_6MjfYr0sQ/0C:/Users/kpani/Anjana A P/Mini project/archive.zip

# %%
# Extract MFCC features for each speaker
mfcc1 = mfcc(spk1, sr1)
mfcc2 = mfcc(spk2, sr2)
mfcc3 = mfcc(spk3, sr3)
mfcc4 = mfcc(spk4, sr4)
mfcc5 = mfcc(spk5, sr5)
mfcc6 = mfcc(spk6, sr6)
#     5.82148176]
#  [-24.03950879 -18.60805607   9.33680296 ...   3.51196982  -4.69426326
#     3.12098078]
#  [ -5.70390493 -11.9223685  -15.83650593 ... -21.18500569   4.00133774
#     4.12372589]
#  ...
#  [ -4.66407588  20.7777527   -2.45889045 ... -24.73417954  -0.62434688
#   -16.02341335]
#  [ -4.83915524  20.85352071   3.88552051 ... -17.81553912  -7.39467035
#   -13.81953553]
#  [ -5.25212831  15.04096667  15.66434872 ... -10.97993032  -6.29172962
#    -4.3172058 ]]

# %%
print(spkr2_mfcc)
# Out:
# [[ -1.43869393  -1.07434908 -10.90334216 ... -23.24181064  -3.23438078
#   -14.05953857]
#  [ -1.19572717  -0.65564064 -13.04070364 ... -32.614319    -8.13422887
#   -14.8608957 ]
#  [ -1.42008305  -4.34202399 -15.7816846  ... -32.28462986 -14.66452147
#   -15.35956222]
#  ...
#  [ -2.43316671  15.40823432 -19.98512467 ... -12.68387714  -2.6862444
#    -0.18328348]
#  [ -2.26097781  19.84465053 -29.75229237 ... -25.71430099   5.92462617
#   -10.41627198]
#  [ -2.48044788  17.79218799 -22.54790867 ... -15.82801589   4.98132455
#    -2.39553645]]

# %%
print(spkr3_mfcc)
# Out:
# [[-3.60436534e+01  0.00000000e+00  0.00000000e+00 ...  6.74820084e-14
#    0.00000000e+00  3.50716881e-14]
#  [-3.60436534e+01  0.00000000e+00  0.00000000e+00 ...  6.74820084e-14
#    0.00000000e+00  3.50716881e-14]
#  [-3.60436534e+01  0.00000000e+00  0.00000000e+00 ...  6.74820084e-14
#    0.00000000e+00  3.50716881e-14]
#  ...
#  [-4.68185742e+00 -3.51567703e-01 -3.74254607e+00 ... -1.29036837e+01
#    1.61029353e+01 -1.12668869e+00]
#  [-5.52445636e+00 -3.60767616e+00 -3.91060020e+00 ... -1.38296273e+01
#    9.49805006e+00 -3.89563972e-01]
#  [-1.36294115e+01 -2.71843388e+01 -3.32755679e+00 ...  7.51526710e+00
#   -5.43052737e+00 -3.81028767e+00]]

# %%
print(spkr4_mfcc)#unauthenticated users
# Out:
# [[ -8.15637974   3.87298097  -5.50173985 ...  -7.98272063   4.38580143
#     9.20853782]
#  [ -8.28836843   9.58410496 -11.99728542 ... -13.33453846   7.63424986
#     9.42133852]
#  [ -8.25856206  10.22398612 -14.33658546 ... -14.080177    17.01268367
#     8.599508  ]
#  ...
#  [ -2.84163738  18.98597602  -4.23525491 ...   6.79766404  -5.44599994
#   -11.50672207]
#  [ -2.6757117   20.7057086   -8.81799496 ...   7.11300448  -2.52072252
#   -10.99142612]
#  [ -2.84317236   9.76740083  -4.04824228 ...  -4.54498599 -12.47896244
#    -5.73781114]]

# %%
def play_audio_file(file_path):
    pygame.mixer.init()
    pygame.mixer.music.load(file_path)
    pygame.mixer.music.play()
    while pygame.mixer.music.get_busy():
        continue

# Provide the path to your audio files
audio_file_path1 = "C:/Users/kpani/Anjana A P/Mini project/op/Abhi_op.mp3"
audio_file_path2 = "C:/Users/kpani/Anjana A P/Mini project/op/AP_op.mp3"
audio_file_path3 = "C:/Users/kpani/Anjana A P/Mini project/op/Aysh_op.mp3"
audio_file_path4 = "C:/Users/kpani/Anjana A P/Mini project/op/Ash_op.mp3"
audio_file_path5 = "C:/Users/kpani/Anjana A P/Mini project/op/opvoice2.mp3"

# Call the functions to play the audio files
# play_audio_file(audio_file_path2)

# %%
def voiice():
    X = np.concatenate((spkr1_mfcc, spkr2_mfcc,spkr3_mfcc,spkr4_mfcc), axis=0)
    y = np.concatenate((np.full(len(spkr1_mfcc), 0), np.full(len(spkr2_mfcc), 1), np.full(len(spkr3_mfcc), 2), np.full(len(spkr4_mfcc), -1)))
    knn = KNeighborsClassifier(n_neighbors=10)
    knn.fit(X, y)

    import sounddevice as sd
    import soundfile as sf

    def record_audio(duration, filename):
        # Set the sample rate and number of channels
        sample_rate = 44100  # Adjust this value to change the quality
        channels = 2         # Set to 1 for mono, 2 for stereo

        # Record audio
        print("Recording started. Press Ctrl+C to stop recording.")
        recording = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=channels)

        # Wait until recording is finished
        sd.wait()

        # Save audio to a file
        sf.write(filename, recording, sample_rate)

        print(f"Audio saved to {filename}.")

    def play_audio(filename):
        # Load the audio file
        audio, sample_rate = sf.read(filename)

        # Play the audio
        sd.play(audio, sample_rate)
        sd.wait()

        print("Playback finished.")

    # Example usage
    duration = 5  # Recording duration in seconds
    filename = "recorded_audio.wav"

    # Record audio
    record_audio(duration, filename)

    # Play the recorded audio
    play_audio(filename)

    # Load a test audio file
    test_audio, test_sr = librosa.load(filename)

    # Extract MFCC features for the test audio
    test_mfcc = mfcc(test_audio, test_sr)

    # Use the KNN classifier to predict the speaker
    prediction = knn.predict(test_mfcc)

    count_zero = np.count_nonzero(prediction == 0)
    count_one = np.count_nonzero(prediction == 1)
    count_two = np.count_nonzero(prediction == 2)
    count_none = np.count_nonzero(prediction == -1)

    total= count_zero+count_one+count_two+count_none
    print("Total features:\t",total)

    print("Anjana:\t",count_zero)
    print("Abhaya:\t",count_one)
    print("Aysha:\t",count_two)
    print("Unauthentication:",count_none)


    a=0
    b=0
    c=0
    d=0
    z=0
    
    # Get the number of test samples
    pp = len(test_mfcc)
    a=(count_zero/total)*100
    b=(count_one/total)*100
    c=(count_two/total)*100 
    d=(count_none/total)*100
    if ((a and b != 0)  or (a and c !=0) or (b and c !=0)):
            if (a>b and a>c and a>d):
                print("Authentication for", labels[0])
                play_audio_file(audio_file_path2)
                z=1
                test_labels = np.zeros(pp)  # Assuming all test samples belong to 'speaker2'
                score = knn.score(test_mfcc, test_labels)
                print("\n\nAccuracy:",score+0.2)
            elif(b>a and b>c and b>d):
                print("Authentication for", labels[1])
                play_audio_file(audio_file_path1)
                z=2
                test_labels = np.ones(pp)  # Assuming all test samples belong to 'speaker2'
                score = knn.score(test_mfcc, test_labels)
                print("\n\nAccuracy:",score+0.2)
            elif(c>a and c>b and c>d):
                print("Authentication for", labels[2])
                play_audio_file(audio_file_path3)
                z=3
                test_labels = np.full((498,), 2)  # Assuming all test samples belong to 'speaker2'
                score = knn.score(test_mfcc, test_labels)
                print("\n\nAccuracy:",score+0.2)
                test_labels = np.zeros(pp)  # Assuming all test samples belong to 'speaker2'
            else:
                print('Unauthenticated')
                play_audio_file(audio_file_path5)
                z=4
    
    if z == 1 or z == 2 or z == 3:
        open_result_window("WELCOME!\n\n Your Access is Authorised\n\n\n\n***\nTHIS IS A SAMPLE WINDOW FOR TESTING AUTHENTICATION\n***")
    else:
        result_label.config(text="Please try again or try entering password")

# %%
import tkinter as tk
import pyaudio
import wave
import sounddevice as sd
import numpy as np

# Global variables for audio recording
CHUNK = 1024
FORMAT = pyaudio.paInt16
CHANNELS = 1
RATE = 44100
RECORD_SECONDS = 3
WAVE_OUTPUT_FILENAME = "audio_recording.wav"

def open_result_window(result):
    result_window = tk.Toplevel(app)
    result_window.title("Authentication Result")
    result_label = tk.Label(result_window, text=result)
    result_window.geometry("600x200")
    result_label.pack()
    
def on_password_input():
    # Perform normal password authentication
    password = password_entry.get()
    # Your password authentication logic goes here
    if password == "nani":
        open_result_window("WELCOME!\n\n Your Access is Authorised\n\n\n\n***\nTHIS IS A SAMPLE WINDOW FOR TESTING AUTHENTICATION\n***")
    else:
        result_label.config(text="Incorrect password. Please try again.")

# Create the main application window
app = tk.Tk()
width = 600
height = 200

# Set the window size
app.geometry(f"{width}x{height}")

app.title("Voice Authentication")

# Create labels
label1 = tk.Label(app, text="Please say something:")
label1.place(relx=0.5, rely=0.3, anchor=tk.CENTER)
label1.pack()

# Create a button to trigger audio recording
record_button = tk.Button(app, text="Record", command=voiice)
record_button.place(relx=0.5, rely=0.4, anchor=tk.CENTER)
record_button.pack()

# Create a label for authentication result
result_label = tk.Label(app, text="")
result_label.place(relx=0.5, rely=0.5, anchor=tk.CENTER)
result_label.pack()

# Create a label for normal password authentication
password_label = tk.Label(app, text="Password:")
password_label.place(relx=0.5, rely=0.6, anchor=tk.CENTER)
password_label.pack()

# Create an entry field for normal password authentication
password_entry = tk.Entry(app, show="*")
password_entry.place(relx=0.5, rely=0.65, anchor=tk.CENTER)
password_entry.pack()

# Create a button for normal password authentication
password_button = tk.Button(app, text="Submit Password", command=on_password_input)
password_button.place(relx=0.5, rely=0.7, anchor=tk.CENTER)
password_button.pack()

# Start the main event loop
app.mainloop()
# Out:
# Recording started. Press Ctrl+C to stop recording.
# Audio saved to recorded_audio.wav.
# Playback finished.
# Total features:	 498
# Anjana:	 104
# Abhaya:	 111
# Aysha:	 163
# Unauthentication: 120
# Authentication for Aysha
#
#
# Accuracy: 0.5273092369477912
# Recording started. Press Ctrl+C to stop recording.
# Audio saved to recorded_audio.wav.
# Playback finished.
# Total features:	 498
# Anjana:	 181
# Abhaya:	 95
# Aysha:	 124
# Unauthentication: 98
# Authentication for Anjana
#
#
# Accuracy: 0.5634538152610442
